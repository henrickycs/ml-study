# %% [markdown]
# Business Understanding
# Data Understanding
# Data Preparation
# Modelling
# Evaluation

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#   Customer ID    Country            State  Postal Code  Gender  \
# 0  7590-VHVEA  Australia  New South Wales         2000  Female
# 1  7590-VHVEG  Australia  New South Wales         2035  Female
# 2  5575-GNVDE  Australia  New South Wales         2014    Male
# 3  3668-QPYBK  Australia  New South Wales         2041    Male
# 4  7795-CFOCW  Australia  New South Wales         2050    Male
#
#    Senior Citizen Partner Dependents  tenure Phone Service  ...  \
# 0               0     Yes         No       1            No  ...
# 1               0     Yes         No       1            No  ...
# 2               0      No         No      34           Yes  ...
# 3               0      No         No       2           Yes  ...
# 4               0      No         No      45            No  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# 1                No           No           No               No
# ...

# %%
len(df)
# Out:
# 7044

# %%
df.columns
# Out:
# Index(['Customer ID', 'Country', 'State', 'Postal Code', 'Gender',
#        'Senior Citizen', 'Partner', 'Dependents', 'tenure', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Customer ID           object
# Country               object
# State                 object
# Postal Code            int64
# Gender                object
# Senior Citizen         int64
# Partner               object
# Dependents            object
# tenure                 int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn                 object
# dtype: object

# %%
for col in df.columns:
    print(col, len(df[col].unique()), df[col].unique())
    
#All data from New South Wales, Australia
# Out:
# Customer ID 7044 ['7590-VHVEA' '7590-VHVEG' '5575-GNVDE' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
# Country 1 ['Australia']
# State 1 ['New South Wales']
# Postal Code 101 [2000 2035 2014 2041 2050 2055 2073 2004 2059 2010 2056 2074 2077 2057
#  2098 2038 2066 2039 2062 2005 2053 2089 2088 2051 2079 2022 2095 2097
#  2090 2032 2082 2083 2037 2049 2021 2099 2085 2001 2007 2048 2046 2017
#  2023 2031 2086 2034 2045 2016 2065 2025 2054 2063 2076 2008 2096 2068
#  2015 2093 2075 2040 2042 2002 2064 2080 2078 2026 2024 2030 2009 2058
#  2067 2094 2033 2084 2020 2052 2036 2100 2047 2092 2044 2006 2027 2061
#  2087 2011 2091 2070 2028 2029 2081 2003 2019 2043 2069 2012 2060 2071
#  2013 2072 2018]
# Gender 2 ['Female' 'Male']
# Senior Citizen 2 [0 1]
# Partner 2 ['Yes' 'No']
# Dependents 2 ['No' 'Yes']
# tenure 73 [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
# ...

# %%
df.describe()
# Out:
#        Postal Code  Senior Citizen       tenure  Monthly Charges
# count  7044.000000     7044.000000  7044.000000      7044.000000
# mean   2050.578081        0.162124    32.366695        64.756736
# std      29.518446        0.368590    24.560582        30.090786
# min    2000.000000        0.000000     0.000000        18.250000
# 25%    2025.000000        0.000000     9.000000        35.500000
# 50%    2051.000000        0.000000    29.000000        70.350000
# 75%    2076.000000        0.000000    55.000000        89.850000
# max    2100.000000        1.000000    72.000000       118.750000

# %%
df.describe(include = ['object'])
# Out:
#        Customer ID    Country            State Gender Partner Dependents  \
# count         7044       7044             7044   7044    7044       7044
# unique        7044          1                1      2       2          2
# top     7590-VHVEA  Australia  New South Wales   Male      No         No
# freq             1       7044             7044   3555    3641       4934
#
#        Phone Service Multiple Lines Internet Service Online Security  \
# count           7044           7044             7044            7044
# unique             2              3                3               3
# top              Yes             No      Fiber optic              No
# freq            6361           3390             3096            3499
#
#        Online Backup Device Protection Tech Support Streaming TV  \
# count           7044              7044         7044         7044
# unique             3                 3            3            3
# ...

# %%
df['Senior Citizen'].dtype=='object'
# Out:
# False

# %%
less_than_2 = []
#get columns that have 2 unique values
for col in df.columns:
    if len(df[col].unique()) == 2 and df[col].dtype == 'object':
        print(col)
        less_than_2.append(col)
# Out:
# Gender
# Partner
# Dependents
# Phone Service
# Paperless Billing
# Churn

# %%
less_than_2
# Out:
# ['Gender',
#  'Partner',
#  'Dependents',
#  'Phone Service',
#  'Paperless Billing',
#  'Churn']

# %%
df.isnull().sum()
#no null values
# Out:
# Customer ID          0
# Country              0
# State                0
# Postal Code          0
# Gender               0
# Senior Citizen       0
# Partner              0
# Dependents           0
# tenure               0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn                0
# dtype: int64

# %%
#importing visualization
import seaborn as sns
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(14,14))
sns.pairplot(df)
plt.show()

# %%
#changing the columns with 2 values into 0 and 1
for col in less_than_2:
    if col == 'Gender':
        df[col] = df[col].apply(lambda x: 1 if x == 'Female' else 0)
    else:
        df[col] = df[col].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
df.dtypes
# Out:
# Customer ID           object
# Country               object
# State                 object
# Postal Code            int64
# Gender                 int64
# Senior Citizen         int64
# Partner                int64
# Dependents             int64
# tenure                 int64
# Phone Service          int64
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing      int64
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn                  int64
# dtype: object

# %%
df[df['Total Charges'] == ' '].head()
#blank values in Total Charges
# Out:
#      Customer ID    Country            State  Postal Code  Gender  \
# 489   4472-LVYGI  Australia  New South Wales         2083       1
# 754   3115-CZMZD  Australia  New South Wales         2043       0
# 937   5709-LVOEQ  Australia  New South Wales         2016       1
# 1083  4367-NUYAO  Australia  New South Wales         2093       0
# 1341  1371-DWPAZ  Australia  New South Wales         2081       1
#
#       Senior Citizen  Partner  Dependents  tenure  Phone Service  ...  \
# 489                0        1           1       0              0  ...
# 754                0        0           1       0              1  ...
# 937                0        1           1       0              1  ...
# 1083               0        1           1       0              1  ...
# 1341               0        1           1       0              0  ...
#
#         Device Protection         Tech Support         Streaming TV  \
# 489                   Yes                  Yes                  Yes
# ...

# %%
df['Total Charges'].replace(' ', 0, inplace = True)
#replacing blank values with 0

# %%
df[df['Total Charges']== ' ']
# Out:
# Empty DataFrame
# Columns: [Customer ID, Country, State, Postal Code, Gender, Senior Citizen, Partner, Dependents, tenure, Phone Service, Multiple Lines, Internet Service, Online Security, Online Backup, Device Protection, Tech Support, Streaming TV, Streaming Movies, Contract, Paperless Billing, Payment Method, Monthly Charges, Total Charges, Churn]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.dtypes
# Out:
# Customer ID           object
# Country               object
# State                 object
# Postal Code            int64
# Gender                 int64
# Senior Citizen         int64
# Partner                int64
# Dependents             int64
# tenure                 int64
# Phone Service          int64
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing      int64
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn                  int64
# dtype: object

# %%
df.corr()
# Out:
# C:\Users\henri\AppData\Local\Temp\ipykernel_13928\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    Postal Code    Gender  Senior Citizen   Partner  \
# Postal Code           1.000000  0.028168        0.011612  0.019248
# Gender                0.028168  1.000000        0.001811  0.001956
# Senior Citizen        0.011612  0.001811        1.000000  0.016413
# Partner               0.019248  0.001956        0.016413  1.000000
# Dependents            0.002838 -0.010609       -0.211135  0.452532
# tenure                0.014939 -0.005288        0.016645  0.379437
# Phone Service        -0.005675  0.006046        0.008761  0.017244
# Paperless Billing     0.000472  0.011871        0.156468 -0.014753
# Monthly Charges      -0.001959  0.014401        0.220222  0.096661
# ...

# %%
plt.figure(figsize = (9,9))
sns.heatmap(df.corr())
plt.show()
# Out:
# C:\Users\henri\AppData\Local\Temp\ipykernel_13928\727768112.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())

# %%
df.drop(['Customer ID','Country','State'], axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['Postal Code', 'Gender', 'Senior Citizen', 'Partner', 'Dependents',
#        'tenure', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn'],
#       dtype='object')

# %%
df['Multiple Lines'].unique()
# Out:
# array(['No phone service', 'No', 'Yes'], dtype=object)

# %%
pd.get_dummies(df['Multiple Lines']).head()
# Out:
#    No  No phone service  Yes
# 0   0                 1    0
# 1   0                 1    0
# 2   1                 0    0
# 3   1                 0    0
# 4   0                 1    0

# %%
df['Total Charges'] = df['Total Charges'].apply(pd.to_numeric)

# %%
plt.figure(figsize = (9,9))
sns.heatmap(df.corr())
plt.show()
# Out:
# C:\Users\henri\AppData\Local\Temp\ipykernel_13928\727768112.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())

# %%
abt = pd.get_dummies(df)

# %%
abt.head()
# Out:
#    Postal Code  Gender  Senior Citizen  Partner  Dependents  tenure  \
# 0         2000       1               0        1           0       1
# 1         2035       1               0        1           0       1
# 2         2014       0               0        0           0      34
# 3         2041       0               0        0           0       2
# 4         2050       0               0        0           0      45
#
#    Phone Service  Paperless Billing  Monthly Charges  Total Charges  ...  \
# 0              0                  1            29.85          29.85  ...
# 1              0                  1            29.85          29.85  ...
# 2              1                  0            56.95        1889.50  ...
# 3              1                  1            53.85         108.15  ...
# 4              0                  0            42.30        1840.75  ...
#
#    Streaming Movies_No  Streaming Movies_No internet service  \
# ...

# %%
abt.dtypes
# Out:
# Postal Code                                   int64
# Gender                                        int64
# Senior Citizen                                int64
# Partner                                       int64
# Dependents                                    int64
# tenure                                        int64
# Phone Service                                 int64
# Paperless Billing                             int64
# Monthly Charges                             float64
# Total Charges                               float64
# Churn                                         int64
# Multiple Lines_No                             uint8
# Multiple Lines_No phone service               uint8
# Multiple Lines_Yes                            uint8
# Internet Service_DSL                          uint8
# Internet Service_Fiber optic                  uint8
# Internet Service_No                           uint8
# Online Security_No                            uint8
# ...

# %%
y = abt['Total Charges']
X = abt.drop('Total Charges', axis = 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.3, random_state = 7)

# %%
print(len(X_train), len(X_test),len(y_train),len(y_test))
# Out:
# 4930 2114 4930 2114

# %%
#preprocessing
from sklearn.pipeline import make_pipeline

# %%
from sklearn.preprocessing import StandardScaler

# %%
#import models
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor

# %%
pipelines = {
    'rf':make_pipeline(StandardScaler(), RandomForestRegressor(random_state = 7)),
    'gb':make_pipeline(StandardScaler(), GradientBoostingRegressor(random_state = 7)),
    'lasso':make_pipeline(StandardScaler(), Lasso(random_state = 7)),
    'ridge':make_pipeline(StandardScaler(), Ridge(random_state = 7)),
    'enet':make_pipeline(StandardScaler(), ElasticNet(random_state = 7))
}

# %%
grid = {
    'rf':{'randomforestregressor__n_estimators':[10,20,30]},
    'gb':{'gradientboostingregressor__alpha':[0.5,0.9,0.99]},
    'lasso':{'lasso__alpha':[0.5,0.9,0.99]},
    'ridge':{'ridge__alpha':[0.5,0.9,0.99]},
    'enet':{'elasticnet__alpha':[0.5,0.9,0.99]}
}

# %%
RandomForestRegressor().get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
from sklearn.model_selection import GridSearchCV

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = GridSearchCV(pipeline, grid[algo], cv = 10, n_jobs =-1)
    model.fit(X_train, y_train)
    fit_models[algo] = model
    print(algo, 'model has been fit')
# Out:
# rf model has been fit
# gb model has been fit
# lasso model has been fit
# ridge model has been fit
# enet model has been fit

# %%
fit_models
# Out:
# {'rf': GridSearchCV(cv=10,
#               estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                         ('randomforestregressor',
#                                          RandomForestRegressor(random_state=7))]),
#               n_jobs=-1,
#               param_grid={'randomforestregressor__n_estimators': [10, 20, 30]}),
#  'gb': GridSearchCV(cv=10,
#               estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                         ('gradientboostingregressor',
#                                          GradientBoostingRegressor(random_state=7))]),
#               n_jobs=-1,
#               param_grid={'gradientboostingregressor__alpha': [0.5, 0.9, 0.99]}),
#  'lasso': GridSearchCV(cv=10,
#               estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                         ('lasso', Lasso(random_state=7))]),
# ...

# %%
fit_models['rf']
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('randomforestregressor',
#                                         RandomForestRegressor(random_state=7))]),
#              n_jobs=-1,
#              param_grid={'randomforestregressor__n_estimators': [10, 20, 30]})

# %%
fit_models['rf'].predict(X_test)
# Out:
# array([1413.91833333, 6061.98166667,   46.495     , ..., 4575.87833333,
#        1371.22333333, 2893.58666667])

# %%
from sklearn.metrics import mean_squared_error

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print('MSE for', algo, 'is', mean_squared_error(y_test, yhat))
    
#Best model --> RandomForestRegressor
# Out:
# MSE for rf is 7195.867633812945
# MSE for gb is 9482.0075207853
# MSE for lasso is 480309.1125751498
# MSE for ridge is 480695.479671743
# MSE for enet is 583247.0888076874

# %%
bestmodel = fit_models['rf'].best_estimator_

# %%
bestmodel.predict(X_test)
# Out:
# array([1413.91833333, 6061.98166667,   46.495     , ..., 4575.87833333,
#        1371.22333333, 2893.58666667])

# %%
import pickle as pkl

# %%
with open('saved_model.pkl', 'wb') as f:
    pkl.dump(bestmodel, f)

# %%
#with open('saved_model.pkl', 'rb') as f:
    #model = pkl.load(f)

# %%
bestmodel
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestregressor',
#                  RandomForestRegressor(n_estimators=30, random_state=7))])

# %%
bestmodel.predict(X_test)
# Out:
# array([1413.91833333, 6061.98166667,   46.495     , ..., 4575.87833333,
#        1371.22333333, 2893.58666667])
